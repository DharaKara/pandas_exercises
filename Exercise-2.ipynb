# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
file = './chipotle.tsv'
chipo = pd.read_csv(file, sep='\t')

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(file, sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
# x-axis -> item name, y-axis -> num of orders
top_5_items = chipo['item_name'].value_counts().head(5)
top_5_items.plot(kind='bar', color='skyblue')

plt.title('Top 5 Items Bought at Chipotle')
plt.xlabel('Item Name')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Chicken Bowl'),
#   Text(1, 0, 'Chicken Burrito'),
#   Text(2, 0, 'Chips and Guacamole'),
#   Text(3, 0, 'Steak Burrito'),
#   Text(4, 0, 'Canned Soft Drink')])

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
# x-axis -> price, y-axis -> items ordered
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
plt.scatter(chipo['item_price'], chipo['quantity'], alpha=0.5, color='green')
plt.title('Number of Items Ordered per Order Price')
plt.xlabel('Order Price ($)')
plt.ylabel('Number of Items Ordered')
# Out:
# Text(0, 0.5, 'Number of Items Ordered')

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.

# %%
# Find percentage of orders that contain a drink item at Chipotle and percentage that does not.
orders_with_drink = chipo['item_name'].str.lower().str.contains('drink').sum()
orders_without_drink = chipo.shape[0] - orders_with_drink

plt.pie([orders_with_drink, orders_without_drink], labels=['Orders with Drink', 'Orders without Drink'], autopct='%1.1f%%', colors=['green', 'red'])
plt.title('Percentage of Orders with Drink Items')
# Out:
# Text(0.5, 1.0, 'Percentage of Orders with Drink Items')
